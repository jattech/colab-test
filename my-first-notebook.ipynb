# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/projects/my-first-notebook
# Out:
# /content/gdrive/My Drive/projects/my-first-notebook

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/My Drive/projects/my-first-notebook/.git/

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name ${username}

# %%
# Out:
# [master b736670] test2
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite my-first-notebook.ipynb (76%)
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/jattech/colab-test.git/'

# %%
# Out:
# [master 82a06bd] test
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite my-first-notebook.ipynb (93%)

# %%
# !git remote add origin {remoteRepo}

# %%
# !git remote -v
# Out:
# origin	https://jattech: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@github.com/jattech/colab-test.git (fetch)
# origin	https://jattech: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@github.com/jattech/colab-test.git (push)

# %%
# !git push -u origin master
# Out:
# Enumerating objects: 6, done.
# Counting objects: 100% (6/6), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 2.36 KiB | 345.00 KiB/s, done.
# Total 6 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/jattech/colab-test.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.
