# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd gdrive/My Drive/projects/my-first-notebook
# Out:
# [Errno 2] No such file or directory: 'gdrive/My Drive/projects/my-first-notebook'
# /content/gdrive/My Drive/projects/my-first-notebook

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/projects/my-first-notebook/.git/

# %%
username = "jattech"
repo = "github.com/jattech/colab-test.git"
token = "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"
remoteRepo = "https://" + username + ":" + token + "@" + repo

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name ${username}

# %%
# !git add .

# %%
# !git commit -m "init"
# Out:
# [master 2067104] init
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite my-first-notebook.ipynb (66%)

# %%
# !git remote add origin {remoteRepo}

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/jattech/colab-test.git (fetch)
# origin	https://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@github.com/jattech/colab-test.git (push)

# %%
# !git push -u origin master
# Out:
# fatal: could not read Password for 'https://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@github.com': No such device or address
