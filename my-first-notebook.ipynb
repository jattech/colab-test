# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd gdrive/My Drive/projects/my-first-notebook

# %%
username = "jattech"
repo = "github.com/jattech/colab-test.git"
token = "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"

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name ${username}

# %%
# !git add .
# Out:
# fatal: not a git repository (or any of the parent directories): .git

# %%
# !git remote add origin https://github.com/jattech/colab-test.git

# %%
# !git push -u origin master
# Out:
# fatal: could not read Username for 'https://github.com': No such device or address
